# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("data/security_issues.csv")
data
# Out:
#                                       repository      number  \
# 0                              matomo-org/matomo   124434256
# 1                              matomo-org/matomo   104426717
# 2                              matomo-org/matomo   452436369
# 3                              matomo-org/matomo  1207536963
# 4                              matomo-org/matomo   333223420
# 5                              matomo-org/matomo   359244903
# 6                              matomo-org/matomo    91337459
# 7                              matomo-org/matomo  1125047930
# 8                              matomo-org/matomo  1109902266
# 9                              matomo-org/matomo   538797554
# 10                             matomo-org/matomo   366818301
# 11                             matomo-org/matomo    37354295
# 12                             matomo-org/matomo   773694921
# 13                             matomo-org/matomo   114489389
# ...
